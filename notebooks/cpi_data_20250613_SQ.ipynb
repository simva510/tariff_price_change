# %% [markdown]
# #### 2 CPI data (Si Qin)
#
# Consumer CPI data is obtained from U.S. Bureau of Labory Statistics (BLS) public FTP server https://download.bls.gov/pub/time.series/cu/
# The raw downloaded data include:
# 1. cu.data.0.Current # Contains all current CPI data series
# 2. cu.series         # Metadata for each series

# %%
# Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load data
cpi_data0 = pd.read_csv("CPI_data/cu.data.0.Current", sep='\t', engine='python')
cpi_meta = pd.read_csv("CPI_data/cu.series", sep='\t', engine='python')
cpi_data0.columns = cpi_data0.columns.str.strip()
cpi_meta.columns = cpi_meta.columns.str.strip()

# %%
print(cpi_data0.head())
print(cpi_data0.columns.tolist())
print(cpi_data0.shape)
print(len(cpi_data0['series_id'].unique()))
# print out all the years and periods
for col in ['year','period']:
	print(f"Unique values in {col}:")
	print(len(cpi_data0[col].unique()))
	print('=' * 40)

cpi_data0['period'].unique() # M13 is the annual average
# Out:
#            series_id  year period  value  footnote_codes
# 0  CUSR0000SA0        1997    M01  159.4             NaN
# 1  CUSR0000SA0        1997    M02  159.7             NaN
# 2  CUSR0000SA0        1997    M03  159.8             NaN
# 3  CUSR0000SA0        1997    M04  159.9             NaN
# 4  CUSR0000SA0        1997    M05  159.9             NaN
# ['series_id', 'year', 'period', 'value', 'footnote_codes']
# (1107696, 5)
# 7935
# Unique values in year:
# 29
# ========================================
# Unique values in period:
# 16
# ========================================
# array(['M01', 'M02', 'M03', 'M04', 'M05', 'M06', 'M07', 'M08', 'M09',
#        'M10', 'M11', 'M12', 'M13', 'S01', 'S02', 'S03'], dtype=object)

# %%
print(cpi_meta.head())
cpi_meta.head()
#cpi_meta.shape
print(len(cpi_meta['series_id'].unique()))
# Out:
#            series_id area_code item_code seasonal periodicity_code base_code  \
# 0  CUSR0000SA0            0000       SA0        S                R         S
# 1  CUSR0000SA0E           0000      SA0E        S                R         S
# 2  CUSR0000SA0L1          0000     SA0L1        S                R         S
# 3  CUSR0000SA0L12         0000    SA0L12        S                R         S
# 4  CUSR0000SA0L12E        0000   SA0L12E        S                R         S
#
#    base_period                                       series_title  \
# 0  1982-84=100  All items in U.S. city average, all urban cons...
# 1  1982-84=100  Energy in U.S. city average, all urban consume...
# 2  1982-84=100  All items less food in U.S. city average, all ...
# 3  1982-84=100  All items less food and shelter in U.S. city a...
# 4  1982-84=100  All items less food, shelter, and energy in U....
#
#    footnote_codes  begin_year begin_period  end_year end_period
# 0             NaN        1947          M01      2025        M05
# 1             NaN        1957          M01      2025        M05
# 2             NaN        1947          M01      2025        M05
# 3             NaN        1967          M01      2025        M05
# 4             NaN        1967          M01      2025        M05
# 8103

# %%
# Extract the series id of U.S. city average, all urban consumers, and not seasonally adjusted
# also exclude all the services
service_keywords = ['services', 'transportation', 'medical', 'education', 'care', 'repair', 'rent', 'tuition', 'fare', 'postage', 'service', 'insurance', 'fee' , 'admission']
pattern = '|'.join(service_keywords)

unadjusted_id = cpi_meta['series_id'][
    cpi_meta['series_title'].str.contains('U.S. city average', case=False) &
    cpi_meta['series_title'].str.contains('all urban consumers', case=False) &
    (cpi_meta['seasonal'] == 'U') &        # Not seasonally adjusted    
    ~cpi_meta['series_title'].str.contains(pattern, case=False, na=False)
    ]

print(len(unadjusted_id))
# Aggregate the CPI data to annual price and use unadjusted value
unj_cpi_data = cpi_data0[cpi_data0['series_id'].isin(unadjusted_id) & (cpi_data0['period'] == 'M13')].drop(columns=['footnote_codes','period'])
print(unj_cpi_data.shape)
print(len(unj_cpi_data['series_id'].unique()))
# Out:
# 573
# (7729, 3)
# 290

# %%
# Targe label: Label big price increase (>5%) from 2017 to 2021 as 1, otherwise 0
# make wide table
wide_cpi = unj_cpi_data.pivot(index='series_id', columns='year', values='value').reset_index()
# add labels
wide_cpi['label'] = np.where((wide_cpi[2021]/wide_cpi[2017]-1) > 0.05, 1, 0)
print(wide_cpi['label'].value_counts())
# merge the description from meta data to the aggreaged data
cpi_all = pd.merge(wide_cpi, cpi_meta[['series_id','series_title']], on = 'series_id', how='left')
# Out:
# label
# 1    184
# 0    106
# Name: count, dtype: int64

# %%
for title in cpi_all[cpi_all['label'] == 1]['series_title']:
    print(title)
# Out:
# All items - old base in U.S. city average, all urban consumers, not seasonally adjusted
# All items in U.S. city average, all urban consumers, not seasonally adjusted
# Energy in U.S. city average, all urban consumers, not seasonally adjusted
# All items less food in U.S. city average, all urban consumers, not seasonally adjusted
# All items less food and shelter in U.S. city average, all urban consumers, not seasonally adjusted
# All items less food, shelter, and energy in U.S. city average, all urban consumers, not seasonally adjusted
# All items less food, shelter, energy, and used cars and trucks in U.S. city average, all urban consumers, not seasonally adjusted
# All items less food and energy in U.S. city average, all urban consumers, not seasonally adjusted
# All items less shelter in U.S. city average, all urban consumers, not seasonally adjusted
# All items less energy in U.S. city average, all urban consumers, not seasonally adjusted
# Commodities in U.S. city average, all urban consumers, not seasonally adjusted
# Energy commodities in U.S. city average, all urban consumers, not seasonally adjusted
# Commodities less food in U.S. city average, all urban consumers, not seasonally adjusted
# Commodities less food and beverages in U.S. city average, all urban consumers, not seasonally adjusted
# Commodities less food and energy commodities in U.S. city average, all urban consumers, not seasonally adjusted
# Durables in U.S. city average, all urban consumers, not seasonally adjusted
# Food and beverages in U.S. city average, all urban consumers, not seasonally adjusted
# Food in U.S. city average, all urban consumers, not seasonally adjusted
# Food at home in U.S. city average, all urban consumers, not seasonally adjusted
# Cereals and bakery products in U.S. city average, all urban consumers, not seasonally adjusted
# Meats, poultry, fish, and eggs in U.S. city average, all urban consumers, not seasonally adjusted
# Meats, poultry, and fish in U.S. city average, all urban consumers, not seasonally adjusted
# Meats in U.S. city average, all urban consumers, not seasonally adjusted
# Fruits and vegetables in U.S. city average, all urban consumers, not seasonally adjusted
# Fresh fruits and vegetables in U.S. city average, all urban consumers, not seasonally adjusted
# Nonalcoholic beverages and beverage materials in U.S. city average, all urban consumers, not seasonally adjusted
# Other food at home in U.S. city average, all urban consumers, not seasonally adjusted
# Alcoholic beverages in U.S. city average, all urban consumers, not seasonally adjusted
# Other goods in U.S. city average, all urban consumers, not seasonally adjusted
# Housing in U.S. city average, all urban consumers, not seasonally adjusted
# Shelter in U.S. city average, all urban consumers, not seasonally adjusted
# Fuels and utilities in U.S. city average, all urban consumers, not seasonally adjusted
# Household energy in U.S. city average, all urban consumers, not seasonally adjusted
# Household furnishings and operations in U.S. city average, all urban consumers, not seasonally adjusted
# Household furnishings and supplies in U.S. city average, all urban consumers, not seasonally adjusted
# Nondurables in U.S. city average, all urban consumers, not seasonally adjusted
# Domestically produced farm food in U.S. city average, all urban consumers, not seasonally adjusted
# Nondurables less food in U.S. city average, all urban consumers, not seasonally adjusted
# Nondurables less food and beverages in U.S. city average, all urban consumers, not seasonally adjusted
# Nondurables less food, beverages, and apparel in U.S. city average, all urban consumers, not seasonally adjusted
# Nondurables less food and apparel in U.S. city average, all urban consumers, not seasonally adjusted
# Recreation in U.S. city average, all urban consumers, not seasonally adjusted
# Men's underwear, nightwear, swimwear, and accessories in U.S. city average, all urban consumers, not seasonally adjusted
# Men's pants and shorts in U.S. city average, all urban consumers, not seasonally adjusted
# Jewelry and watches in U.S. city average, all urban consumers, not seasonally adjusted
# Watches in U.S. city average, all urban consumers, not seasonally adjusted
# Bakery products in U.S. city average, all urban consumers, not seasonally adjusted
# Bread in U.S. city average, all urban consumers, not seasonally adjusted
# Fresh biscuits, rolls, muffins in U.S. city average, all urban consumers, not seasonally adjusted
# Cakes, cupcakes, and cookies in U.S. city average, all urban consumers, not seasonally adjusted
# Other bakery products in U.S. city average, all urban consumers, not seasonally adjusted
# Beef and veal in U.S. city average, all urban consumers, not seasonally adjusted
# Uncooked ground beef in U.S. city average, all urban consumers, not seasonally adjusted
# Uncooked beef roasts in U.S. city average, all urban consumers, not seasonally adjusted
# Uncooked beef steaks in U.S. city average, all urban consumers, not seasonally adjusted
# Uncooked other beef and veal in U.S. city average, all urban consumers, not seasonally adjusted
# Pork in U.S. city average, all urban consumers, not seasonally adjusted
# Bacon, breakfast sausage, and related products in U.S. city average, all urban consumers, not seasonally adjusted
# Ham in U.S. city average, all urban consumers, not seasonally adjusted
# Pork chops in U.S. city average, all urban consumers, not seasonally adjusted
# Other pork including roasts, steaks, and ribs in U.S. city average, all urban consumers, not seasonally adjusted
# Other meats in U.S. city average, all urban consumers, not seasonally adjusted
# Poultry in U.S. city average, all urban consumers, not seasonally adjusted
# Chicken in U.S. city average, all urban consumers, not seasonally adjusted
# Other uncooked poultry including turkey in U.S. city average, all urban consumers, not seasonally adjusted
# Fish and seafood in U.S. city average, all urban consumers, not seasonally adjusted
# Fresh fish and seafood in U.S. city average, all urban consumers, not seasonally adjusted
# Processed fish and seafood in U.S. city average, all urban consumers, not seasonally adjusted
# Eggs in U.S. city average, all urban consumers, not seasonally adjusted
# Dairy and related products in U.S. city average, all urban consumers, not seasonally adjusted
# Milk in U.S. city average, all urban consumers, not seasonally adjusted
# Cheese and related products in U.S. city average, all urban consumers, not seasonally adjusted
# Ice cream and related products in U.S. city average, all urban consumers, not seasonally adjusted
# Citrus fruits in U.S. city average, all urban consumers, not seasonally adjusted
# Other fresh fruits in U.S. city average, all urban consumers, not seasonally adjusted
# Fresh vegetables in U.S. city average, all urban consumers, not seasonally adjusted
# Potatoes in U.S. city average, all urban consumers, not seasonally adjusted
# Lettuce in U.S. city average, all urban consumers, not seasonally adjusted
# Tomatoes in U.S. city average, all urban consumers, not seasonally adjusted
# Other fresh vegetables in U.S. city average, all urban consumers, not seasonally adjusted
# Processed fruits and vegetables in U.S. city average, all urban consumers, not seasonally adjusted
# Canned fruits and vegetables in U.S. city average, all urban consumers, not seasonally adjusted
# Juices and nonalcoholic drinks in U.S. city average, all urban consumers, not seasonally adjusted
# Carbonated drinks in U.S. city average, all urban consumers, not seasonally adjusted
# Nonfrozen noncarbonated juices and drinks in U.S. city average, all urban consumers, not seasonally adjusted
# Other beverage materials including tea in U.S. city average, all urban consumers, not seasonally adjusted
# Sugar and sweets in U.S. city average, all urban consumers, not seasonally adjusted
# Sugar and sugar substitutes in U.S. city average, all urban consumers, not seasonally adjusted
# Candy and chewing gum in U.S. city average, all urban consumers, not seasonally adjusted
# Fats and oils in U.S. city average, all urban consumers, not seasonally adjusted
# Salad dressing in U.S. city average, all urban consumers, not seasonally adjusted
# Other fats and oils including peanut butter in U.S. city average, all urban consumers, not seasonally adjusted
# Other foods in U.S. city average, all urban consumers, not seasonally adjusted
# Spices, seasonings, condiments, sauces in U.S. city average, all urban consumers, not seasonally adjusted
# Baby Food and Formula in U.S. city average, all urban consumers, not seasonally adjusted
# Other miscellaneous foods in U.S. city average, all urban consumers, not seasonally adjusted
# Food away from home in U.S. city average, all urban consumers, not seasonally adjusted
# Food from vending machines and mobile vendors in U.S. city average, all urban consumers, not seasonally adjusted
# Other food away from home in U.S. city average, all urban consumers, not seasonally adjusted
# Alcoholic beverages at home in U.S. city average, all urban consumers, not seasonally adjusted
# Beer, ale, and other malt beverages at home in U.S. city average, all urban consumers, not seasonally adjusted
# Alcoholic beverages away from home in U.S. city average, all urban consumers, not seasonally adjusted
# Tobacco and smoking products in U.S. city average, all urban consumers, not seasonally adjusted
# Cigarettes in U.S. city average, all urban consumers, not seasonally adjusted
# Tobacco products other than cigarettes in U.S. city average, all urban consumers, not seasonally adjusted
# Funeral expenses in U.S. city average, all urban consumers, not seasonally adjusted
# Housing at school, excluding board in U.S. city average, all urban consumers, not seasonally adjusted
# Fuel oil and other fuels in U.S. city average, all urban consumers, not seasonally adjusted
# Fuel oil in U.S. city average, all urban consumers, not seasonally adjusted
# Propane, kerosene, and firewood in U.S. city average, all urban consumers, not seasonally adjusted
# Electricity in U.S. city average, all urban consumers, not seasonally adjusted
# Water and sewerage maintenance in U.S. city average, all urban consumers, not seasonally adjusted
# Garbage and trash collection in U.S. city average, all urban consumers, not seasonally adjusted
# Floor coverings in U.S. city average, all urban consumers, not seasonally adjusted
# Furniture and bedding in U.S. city average, all urban consumers, not seasonally adjusted
# Bedroom furniture in U.S. city average, all urban consumers, not seasonally adjusted
# Living room, kitchen, and dining room furniture in U.S. city average, all urban consumers, not seasonally adjusted
# Other furniture in U.S. city average, all urban consumers, not seasonally adjusted
# Appliances in U.S. city average, all urban consumers, not seasonally adjusted
# Major appliances in U.S. city average, all urban consumers, not seasonally adjusted
# Other appliances in U.S. city average, all urban consumers, not seasonally adjusted
# Indoor plants and flowers in U.S. city average, all urban consumers, not seasonally adjusted
# Tools, hardware, outdoor equipment and supplies in U.S. city average, all urban consumers, not seasonally adjusted
# Tools, hardware and supplies in U.S. city average, all urban consumers, not seasonally adjusted
# Outdoor equipment and supplies in U.S. city average, all urban consumers, not seasonally adjusted
# Housekeeping supplies in U.S. city average, all urban consumers, not seasonally adjusted
# Household cleaning products in U.S. city average, all urban consumers, not seasonally adjusted
# Household paper products in U.S. city average, all urban consumers, not seasonally adjusted
# Household operations in U.S. city average, all urban consumers, not seasonally adjusted
# Moving, storage, freight expense in U.S. city average, all urban consumers, not seasonally adjusted
# Video and audio in U.S. city average, all urban consumers, not seasonally adjusted
# Sporting goods in U.S. city average, all urban consumers, not seasonally adjusted
# Sports vehicles including bicycles in U.S. city average, all urban consumers, not seasonally adjusted
# Recreational reading materials in U.S. city average, all urban consumers, not seasonally adjusted
# Newspapers and magazines in U.S. city average, all urban consumers, not seasonally adjusted
# New and used motor vehicles in U.S. city average, all urban consumers, not seasonally adjusted
# New vehicles in U.S. city average, all urban consumers, not seasonally adjusted
# Used cars and trucks in U.S. city average, all urban consumers, not seasonally adjusted
# Motor fuel in U.S. city average, all urban consumers, not seasonally adjusted
# Gasoline (all types) in U.S. city average, all urban consumers, not seasonally adjusted
# Other motor fuels in U.S. city average, all urban consumers, not seasonally adjusted
# Motor vehicle parts and equipment in U.S. city average, all urban consumers, not seasonally adjusted
# Tires in U.S. city average, all urban consumers, not seasonally adjusted
# Vehicle accessories other than tires in U.S. city average, all urban consumers, not seasonally adjusted
# Motor vehicle body work in U.S. city average, all urban consumers, not seasonally adjusted
# Motor vehicle maintenance and servicing in U.S. city average, all urban consumers, not seasonally adjusted
# White bread in U.S. city average, all urban consumers, not seasonally adjusted
# Bread other than white in U.S. city average, all urban consumers, not seasonally adjusted
# Fresh cakes and cupcakes in U.S. city average, all urban consumers, not seasonally adjusted
# Cookies in U.S. city average, all urban consumers, not seasonally adjusted
# Crackers, bread, and cracker products in U.S. city average, all urban consumers, not seasonally adjusted
# Bacon and related products in U.S. city average, all urban consumers, not seasonally adjusted
# Breakfast sausage and related products in U.S. city average, all urban consumers, not seasonally adjusted
# Ham, excluding canned in U.S. city average, all urban consumers, not seasonally adjusted
# Frankfurters in U.S. city average, all urban consumers, not seasonally adjusted
# Lunchmeats in U.S. city average, all urban consumers, not seasonally adjusted
# Fresh whole chicken in U.S. city average, all urban consumers, not seasonally adjusted
# Fresh and frozen chicken parts in U.S. city average, all urban consumers, not seasonally adjusted
# Shelf stable fish and seafood in U.S. city average, all urban consumers, not seasonally adjusted
# Frozen fish and seafood in U.S. city average, all urban consumers, not seasonally adjusted
# Fresh whole milk in U.S. city average, all urban consumers, not seasonally adjusted
# Fresh milk other than whole in U.S. city average, all urban consumers, not seasonally adjusted
# Canned fruits in U.S. city average, all urban consumers, not seasonally adjusted
# Canned vegetables in U.S. city average, all urban consumers, not seasonally adjusted
# Peanut butter in U.S. city average, all urban consumers, not seasonally adjusted
# Salt and other seasonings and spices in U.S. city average, all urban consumers, not seasonally adjusted
# Olives, pickles, relishes in U.S. city average, all urban consumers, not seasonally adjusted
# Sauces and gravies in U.S. city average, all urban consumers, not seasonally adjusted
# Prepared salads in U.S. city average, all urban consumers, not seasonally adjusted
# Distilled spirits, excluding whiskey, at home in U.S. city average, all urban consumers, not seasonally adjusted
# Beer, ale, and other malt beverages away from home in U.S. city average, all urban consumers, not seasonally adjusted
# Wine away from home in U.S. city average, all urban consumers, not seasonally adjusted
# Distilled spirits away from home in U.S. city average, all urban consumers, not seasonally adjusted
# Laundry equipment in U.S. city average, all urban consumers, not seasonally adjusted
# Stationery, stationery supplies, gift wrap in U.S. city average, all urban consumers, not seasonally adjusted
# New cars in U.S. city average, all urban consumers, not seasonally adjusted
# New cars and trucks in U.S. city average, all urban consumers, not seasonally adjusted
# New trucks in U.S. city average, all urban consumers, not seasonally adjusted
# Gasoline, unleaded regular in U.S. city average, all urban consumers, not seasonally adjusted
# Gasoline, unleaded midgrade in U.S. city average, all urban consumers, not seasonally adjusted
# Gasoline, unleaded premium in U.S. city average, all urban consumers, not seasonally adjusted
# Motor oil, coolant, and fluids in U.S. city average, all urban consumers, not seasonally adjusted
# Vehicle parts and equipment other than tires in U.S. city average, all urban consumers, not seasonally adjusted
# Photographic equipment in U.S. city average, all urban consumers, not seasonally adjusted

# %% [markdown]
# Most of the items with more than 5% increase form 2017 to 2021 are food, housing. Relevent items to the goods imported from China are:
# - Men's underwear, nightwear, swimwear, and accessories.
# - Men's pants and shorts.
# - Floor coverings.
# - Furniture and bedding.
# - Bedroom furniture.
# - Living room, kitchen, and dining room furniture.
# - Other furniture.
# - Appliances.
# - Major appliances.
# - Other appliances.
# - Tools, hardware, outdoor equipment and supplies.
# - Tools, hardware and supplies.
# - Outdoor equipment and supplies.
# - Housekeeping supplies.
# - Household cleaning products.
# - Household paper products.
# - Household operations.
# - Sports vehicles including bicycles
# - New and used motor vehicles
# - New vehicles
# - Used cars and trucks

# %%
# Define keyword groups for CPI categories
cpi_keywords = {
    "men_clothing": ["underwear", "nightwear", "swimwear", "pants", "shorts"],
    "floor_coverings": ["carpet", "rug", "floor covering"],
    "furniture": ["furniture", "bedding"],
    "appliances": ["appliance", "refrigerator", "washer", "dryer", "microwave"],
    "tools_hardware": ["tools", "hardware", "lawn", "garden", "outdoor equipment"],
    "cleaning_supplies": ["cleaning", "detergent", "housekeeping"],
    "paper_products": ["toilet paper", "paper towel", "tissue"],
    "household_operations": ["household operation"],
    "sports_vehicles": ["bicycle", "sports vehicle"],
    "motor_vehicles": ["automobile", "car", "passenger vehicle", "truck", "new car", "used car"]
}

# Convert description to lowercase for case-insensitive matching
tariff_df["Description_lower"] = tariff_df["Description"].str.lower()

# Initialize label column
tariff_df["label"] = 0

# Match descriptions to keyword lists
for category, keywords in cpi_keywords.items():
    for keyword in keywords:
        match_mask = tariff_df["Description_lower"].str.contains(keyword, na=False)
        tariff_df.loc[match_mask, "label"] = 1
        tariff_df.loc[match_mask, "matched_category"] = category

# Optional: keep only HTS and match info
matched_df = tariff_df[tariff_df["label"] == 1][["HTS", "Description", "matched_category"]].drop_duplicates()

# Save result
matched_df.to_csv("matched_hts_to_cpi.csv", index=False)

print("Matching complete. Saved to 'matched_hts_to_cpi.csv'.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 16
#       2 cpi_keywords = {
#       3     "men_clothing": ["underwear", "nightwear", "swimwear", "pants", "shorts"],
#       4     "floor_coverings": ["carpet", "rug", "floor covering"],
#    (...)
#      12     "motor_vehicles": ["automobile", "car", "passenger vehicle", "truck", "new car", "used car"]
#      13 }
#      15 # Convert description to lowercase for case-insensitive matching
# ---> 16 tariff_df["Description_lower"] = tariff_df["Description"].str.lower()
#      18 # Initialize label column
#      19 tariff_df["label"] = 0
#
# NameError: name 'tariff_df' is not defined
